# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib

# %%
data = pd.read_csv(r'/media/mridul/EADEBA2FDEB9F443/Project_data_science_illustration/data_sets/clustering_data.csv')
print(data.tail())
# Out:
#               x           y  color
# 331  638.916471  323.569096      1
# 332  542.005901  347.527070      0
# 333  611.964612  377.254978      0
# 334  520.654168  455.996453      0
# 335  594.479314  392.901455      0

# %%
x = np.array(data['x'])
y = np.array(data['y'])
labels = np.array(data['color'])
colors = ['red','green','blue','purple']

# %%
plt.scatter(x, y, c=labels, cmap=matplotlib.colors.ListedColormap(colors))

# %%
def gini(p):
    return (p) * (1 - (p)) + (1 - p) * (1 - (1 - p))
def entropy (p):
    return - p * np.log2(p) - (1 - p) * np.log2((1 - p))
